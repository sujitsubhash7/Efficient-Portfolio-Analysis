# %%
## Initialized Imports

import os
import requests
import pandas as pd
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
from MCForecastTools import MCSimulation
import json

# %matplotlib inline

load_dotenv()
# Out:
# True

# %%
# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

# Create the Alpaca API object
alpaca = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2")

# Format current date as ISO format
start = pd.Timestamp("2020-07-10", tz="America/New_York").isoformat()
end = pd.Timestamp("2021-07-10", tz="America/New_York").isoformat()

# Set the tickers
tickers = ["AGG", "SPY","VTI","VTV", "VOE", "VBR", "VEA", "AXP", "AMGN", "AAPL", "BA", "CAT", "CSCO", "CVX", "GS", "HD", "HON", "IBM",
"INTC", "JNJ", "KO", "JPM", "MCD", "MMM", "MRK", "MSFT", "NKE", "PG", 
"TRV", "UNH", "CRM", "VZ", "V", "WBA", "WMT", "DIS", "DOW", "BNDX", "MUB"]

# Set timeframe to one day ('1D') for the Alpaca API
timeframe = "1D"

# %%
# Get current closing prices for FB and TWTR
df_portfolio = alpaca.get_barset(
    tickers,
    timeframe,
    start = start,
    end = end
).df

# Display sample data
df_portfolio
# Out:
#                              AAPL                                          \
#                              open     high       low     close     volume
# time
# 2021-02-17 00:00:00-05:00  131.25  132.220  129.4700  130.8400   92298227
# 2021-02-18 00:00:00-05:00  129.20  129.995  127.4100  129.7127   90601312
# 2021-02-19 00:00:00-05:00  130.24  130.710  128.8000  129.8500   79960220
# 2021-02-22 00:00:00-05:00  128.01  129.720  125.6000  126.0100   93993093
# 2021-02-23 00:00:00-05:00  123.76  126.710  118.3900  125.8500  148286878
# ...                           ...      ...       ...       ...        ...
# 2021-07-02 00:00:00-04:00  137.92  140.000  137.7450  139.9600   69160944
# 2021-07-06 00:00:00-04:00  140.10  143.150  140.0700  142.0200   97272256
# 2021-07-07 00:00:00-04:00  143.54  144.890  142.6600  144.5900   93223232
# 2021-07-08 00:00:00-04:00  141.57  144.060  140.6650  143.3200   94133450
# 2021-07-09 00:00:00-04:00  142.73  145.650  142.6522  145.1100   89995907
#
# ...

# %%
# Pick the closing prices for the asset classes
df_close = pd.DataFrame()

# fetch closing prices
df_close["AGG"] = df_portfolio["AGG"]["close"]
df_close["SPY"] = df_portfolio["SPY"]["close"]
df_close["VTI"] = df_portfolio["VTI"]["close"]
df_close["VTV"] = df_portfolio["VTV"]["close"]
df_close["VOE"] = df_portfolio["VOE"]["close"]
df_close["VBR"] = df_portfolio["VBR"]["close"]
df_close["VEA"] = df_portfolio["VEA"]["close"]
df_close["AXP"] = df_portfolio["AXP"]["close"]
df_close["AMGN"] = df_portfolio["AMGN"]["close"]
df_close["AAPL"] = df_portfolio["AAPL"]["close"]
df_close["BA"] = df_portfolio["BA"]["close"]
df_close["CAT"] = df_portfolio["CAT"]["close"]
df_close["CSCO"] = df_portfolio["CSCO"]["close"]
df_close["AGG"] = df_portfolio["AGG"]["close"]
df_close["CVX"] = df_portfolio["CVX"]["close"]
df_close["GS"] = df_portfolio["GS"]["close"]
df_close["HD"] = df_portfolio["HD"]["close"]
df_close["HON"] = df_portfolio["HON"]["close"]
df_close["IBM"] = df_portfolio["IBM"]["close"]
df_close["INTC"] = df_portfolio["INTC"]["close"]
df_close["JNJ"] = df_portfolio["JNJ"]["close"]
df_close["KO"] = df_portfolio["KO"]["close"]
df_close["JPM"] = df_portfolio["JPM"]["close"]
df_close["MCD"] = df_portfolio["MCD"]["close"]
df_close["MMM"] = df_portfolio["MMM"]["close"]
df_close["MRK"] = df_portfolio["MRK"]["close"]
df_close["MSFT"] = df_portfolio["MSFT"]["close"]
df_close["NKE"] = df_portfolio["NKE"]["close"]
df_close["PG"] = df_portfolio["PG"]["close"]
df_close["TRV"] = df_portfolio["TRV"]["close"]
df_close["UNH"] = df_portfolio["UNH"]["close"]
df_close["CRM"] = df_portfolio["CRM"]["close"]
df_close["VZ"] = df_portfolio["VZ"]["close"]
df_close["V"] = df_portfolio["V"]["close"]
df_close["WBA"] = df_portfolio["WBA"]["close"]
df_close["WMT"] = df_portfolio["WMT"]["close"]
df_close["DIS"] = df_portfolio["DIS"]["close"]
df_close["DOW"] = df_portfolio["DOW"]["close"]
df_close["BNDX"] = df_portfolio["BNDX"]["close"]
df_close["MUB"] = df_portfolio["MUB"]["close"]



# Drop the time component of the date
df_close.index = df_close.index.date
# Display sample data
df_close
# Out:
#                AGG     SPY     VTI     VTV     VOE     VBR     VEA     AXP  \
# 2021-02-17  116.28  392.43  206.74  125.12  127.92  157.45  49.590  128.57
# 2021-02-18  116.20  390.75  205.56  124.42  127.13  155.44  49.280  128.49
# 2021-02-19  115.83  390.02  205.94  124.86  128.89  158.50  49.490  131.74
# 2021-02-22  115.49  387.11  203.97  125.69  129.58  159.60  49.350  135.94
# 2021-02-23  115.52  387.50  203.92  126.15  130.09  159.99  49.370  136.95
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 2021-07-02  115.37  433.75  225.28  138.80  141.69  174.39  51.870  168.51
# 2021-07-06  115.75  432.90  224.68  137.38  139.98  171.33  51.530  169.58
# 2021-07-07  115.95  434.43  225.08  137.87  140.29  170.95  51.735  170.99
# 2021-07-08  116.06  430.95  223.17  136.52  138.66  168.84  50.980  167.51
# 2021-07-09  115.69  435.48  225.87  138.52  141.31  173.03  51.870  171.94
#
# ...

# %%
# Set Alpaca API key and secret
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

# Create the Alpaca API object
alpaca = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2")
alpaca

# %%
# Format current date as ISO format
start = pd.Timestamp("2020-07-10", tz="America/New_York").isoformat()
end = pd.Timestamp("2021-07-10", tz="America/New_York").isoformat()

# Set the tickers
tickers = ["GLD", "BAR", "UGL", "DBP"]

# Set timeframe to '1D' for Alpaca API
timeframe = "1D"

# %%
# Get current closing prices for SPY and AGG
df_portfolio_2 = alpaca.get_barset(
    tickers,
    timeframe,
    start = start,
    end = end
).df

# Preview DataFrame
df_portfolio_2
# Out:
#                              BAR                                      DBP  \
#                             open     high      low   close  volume   open
# time
# 2021-02-17 00:00:00-05:00  17.69  17.7389  17.5900  17.635  422768  50.28
# 2021-02-18 00:00:00-05:00  17.70  17.7300  17.5711  17.630  270499  50.31
# 2021-02-19 00:00:00-05:00  17.66  17.8000  17.6600  17.700  344937  50.22
# 2021-02-22 00:00:00-05:00  17.86  18.0150  17.8450  17.980  372080  50.63
# 2021-02-23 00:00:00-05:00  17.96  17.9900  17.8500  17.930  348136  51.15
# ...                          ...      ...      ...     ...     ...    ...
# 2021-07-02 00:00:00-04:00  17.77  17.7999  17.6600  17.760  325957  49.84
# 2021-07-06 00:00:00-04:00  17.95  18.0000  17.7900  17.850  288703  50.30
# 2021-07-07 00:00:00-04:00  17.91  17.9600  17.8500  17.905  304676  50.13
# 2021-07-08 00:00:00-04:00  18.02  18.0100  17.8200  17.900  187830  50.30
# 2021-07-09 00:00:00-04:00  17.92  18.0000  17.9019  17.960  293683  49.78
#
# ...

# %%
# Pick AGG and SPY close prices
df_closing_prices = pd.DataFrame()

# fetch closing prices
df_closing_prices["GLD"] = df_portfolio_2["GLD"]["close"]
df_closing_prices["BAR"] = df_portfolio_2["BAR"]["close"]
df_closing_prices["UGL"] = df_portfolio_2["UGL"]["close"]
df_closing_prices["DBP"] = df_portfolio_2["DBP"]["close"]


# Drop the time component of the date
df_closing_prices.index = df_closing_prices.index.date

# Display sample data
df_closing_prices
# Out:
#                GLD     BAR      UGL      DBP
# 2021-02-17  166.32  17.635  58.5400  50.0550
# 2021-02-18  166.32  17.630  58.4850  49.9400
# 2021-02-19  167.00  17.700  58.9800  50.2213
# 2021-02-22  169.47  17.980  60.7500  51.1700
# 2021-02-23  169.12  17.930  60.5299  50.7800
# ...            ...     ...      ...      ...
# 2021-07-02  167.32  17.760  58.3200  49.8600
# 2021-07-06  168.12  17.850  58.9500  49.7600
# 2021-07-07  168.78  17.905  59.3800  49.9500
# 2021-07-08  168.67  17.900  59.3000  49.7799
# 2021-07-09  169.20  17.960  59.6700  50.1000
#
# [100 rows x 4 columns]

# %%
# Data Cleaning 

## Concatenating all dataframes to merge columns into a single dataframe 
df_final = pd.concat([df_closing_prices,df_close], axis= 'columns', join='outer')

## Identified and dropped null records in the combined portfolio
df_final = df_final.dropna()

## Dropped duplicates in the combined protfolio
df_final = df_final.drop_duplicates()

df_final.head()
# Out:
#                GLD     BAR      UGL      DBP     AGG     SPY     VTI     VTV  \
# 2021-02-17  166.32  17.635  58.5400  50.0550  116.28  392.43  206.74  125.12
# 2021-02-18  166.32  17.630  58.4850  49.9400  116.20  390.75  205.56  124.42
# 2021-02-19  167.00  17.700  58.9800  50.2213  115.83  390.02  205.94  124.86
# 2021-02-22  169.47  17.980  60.7500  51.1700  115.49  387.11  203.97  125.69
# 2021-02-23  169.12  17.930  60.5299  50.7800  115.52  387.50  203.92  126.15
#
#                VOE     VBR  ...     UNH     CRM     VZ       V    WBA     WMT  \
# 2021-02-17  127.92  157.45  ...  326.94  247.67  56.99  207.52  49.56  147.39
# 2021-02-18  127.13  155.44  ...  328.51  247.05  56.97  209.41  48.91  137.62
# 2021-02-19  128.89  158.50  ...  324.65  246.51  56.45  204.92  48.86  138.37
# 2021-02-22  129.58  159.60  ...  327.76  240.96  56.45  208.35  48.88  137.72
# 2021-02-23  130.09  159.99  ...  329.60  235.64  57.02  212.14  48.41  135.43
#
# ...
